# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    source = []
    target = []
    
    for sentence in source_text.split("\n"):
        new_sentence = []
        for word in sentence.split(" "):
            if word:
                new_sentence.append(source_vocab_to_int[word])
        source.append(new_sentence)

    for sentence in target_text.split("\n"):
        new_sentence = []
        for word in sentence.split(" "):
            if word:
                new_sentence.append(target_vocab_to_int[word])
        new_sentence.append(target_vocab_to_int['<EOS>'])
        target.append(new_sentence)
    
    return source, target

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.2.1
# /home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    inputs = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None])
    learning_rate = tf.placeholder(tf.float32)
    keep_probability = tf.placeholder(tf.float32, name="keep_prob")
    target_sequence_length = tf.placeholder(tf.int32, [None], name="target_sequence_length")
    max_target_sequence_length = tf.reduce_max(target_sequence_length, name="max_target_len")
    source_sequence_length = tf.placeholder(tf.int32, [None], name="source_sequence_length")
    return (
        inputs,
        targets,
        learning_rate,
        keep_probability,
        target_sequence_length,
        max_target_sequence_length,
        source_sequence_length
    )

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_2/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/runpy.py", line 193, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance\n    app.start()', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 477, in start\n    ioloop.IOLoop.instance().start()', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tornado/ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 399, in execute_request\n    user_expressions, allow_stdin)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 533, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2808, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-7-8c7ab67d87b6>", line 27, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/marcio/Workspace/deep-learning/language-translation/problem_unittests.py", line 106, in test_model_inputs\n    assert tf.assert_rank(lr, 0, message=\'Learning Rate has wrong rank\')', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=sum ...
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_3/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/runpy.py", line 193, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance\n    app.start()', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 477, in start\n    ioloop.IOLoop.instance().start()', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/zmq/eventloop/ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tornado/ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 399, in execute_request\n    user_expressions, allow_stdin)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 533, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2698, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2808, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-7-8c7ab67d87b6>", line 27, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/marcio/Workspace/deep-learning/language-translation/problem_unittests.py", line 107, in test_model_inputs\n    assert tf.assert_rank(keep_prob, 0, message=\'Keep Probability has wrong rank\')', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/home/marcio/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, sum ...
# ==================================
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    last_word_removed = tf.strided_slice(
        target_data,
        [0, 0],
        [batch_size, -1],
        [1, 1]
    )
    return tf.concat(
        [
            tf.fill(
                [batch_size, 1], 
                target_vocab_to_int["<GO>"]
            ),
            last_word_removed
        ],
        1
    )

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    def create_cell():
        lstm = tf.contrib.rnn.LSTMCell(rnn_size)
        return tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    
    embedded_input = tf.contrib.layers.embed_sequence(
        rnn_inputs,
        vocab_size = source_vocab_size,
        embed_dim = encoding_embedding_size
    )
    
    cell = tf.contrib.rnn.MultiRNNCell([create_cell() for i in range(num_layers)])

    return tf.nn.dynamic_rnn(
        cell,
        embedded_input,
        sequence_length=source_sequence_length,
        dtype=tf.float32
    )

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    training_helper = tf.contrib.seq2seq.TrainingHelper(
        dec_embed_input,
        target_sequence_length,
        time_major=False
    )
    basic_decoder = tf.contrib.seq2seq.BasicDecoder(
        dec_cell,
        training_helper,
        encoder_state,
        output_layer
    )
    final_outputs, final_state, final_sequence_lengths = tf.contrib.seq2seq.dynamic_decode(
        basic_decoder,
        impute_finished=True,
        maximum_iterations=max_summary_length
    )
    # Not using `keep_prob`
    return final_outputs


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    start_tokens = tf.tile(
        tf.constant(
            [start_of_sequence_id],
            dtype=tf.int32
        ),
        [batch_size],
        name='start_tokens'
    )
    embedding_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(
        dec_embeddings,
        start_tokens,
        end_of_sequence_id
    )
    basic_decoder = tf.contrib.seq2seq.BasicDecoder(
        dec_cell,
        embedding_helper,
        encoder_state,
        output_layer
    )
    final_outputs, final_state, final_sequence_lengths = tf.contrib.seq2seq.dynamic_decode(
        basic_decoder,
        impute_finished=True,
        maximum_iterations=max_target_sequence_length
    )
    return final_outputs


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # Embedding the target sequences:
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    # Decoder LSTM cell:
    def create_cell():
        lstm = tf.contrib.rnn.LSTMCell(
            rnn_size,
            initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2)
        )
        return tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    
    dec_cell = tf.contrib.rnn.MultiRNNCell([create_cell() for i in range(num_layers)])
    
    # Create output layer:
    output_layer = Dense(
        target_vocab_size,
        kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1)
    )
    
    # Training decoder:
    with tf.variable_scope("decode"):
        training_logits = decoding_layer_train(
            encoder_state,
            dec_cell,
            dec_embed_input,
            target_sequence_length,
            max_target_sequence_length,
            output_layer,
            keep_prob
        )
    
    # Inference decoder (reuses the same parameters above:
    with tf.variable_scope("decode", reuse=True):
        inference_logits = decoding_layer_infer(
            encoder_state, 
            dec_cell, 
            dec_embeddings, 
            target_vocab_to_int["<GO>"], 
            target_vocab_to_int["<EOS>"], 
            max_target_sequence_length, 
            target_vocab_size, 
            output_layer, 
            batch_size, 
            keep_prob
        )
    
    return training_logits, inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    _, enc_state = encoding_layer(
        input_data, 
        rnn_size, 
        num_layers, 
        keep_prob, 
        source_sequence_length, 
        source_vocab_size, 
        enc_embedding_size
    )
    
    dec_input = process_decoder_input(
        target_data, 
        target_vocab_to_int, 
        batch_size
    )
    
    return decoding_layer(
        dec_input, 
        enc_state, 
        target_sequence_length, 
        max_target_sentence_length, 
        rnn_size, 
        num_layers, 
        target_vocab_to_int, 
        target_vocab_size, 
        batch_size, 
        keep_prob, 
        dec_embedding_size
    )


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 15
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 200
# Number of Layers
num_layers = 3
# Embedding Size
encoding_embedding_size = 100
decoding_embedding_size = 100
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.75
display_step = 20

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   20/538 - Train Accuracy: 0.3579, Validation Accuracy: 0.3999, Loss: 3.1343
# Epoch   0 Batch   40/538 - Train Accuracy: 0.4505, Validation Accuracy: 0.4542, Loss: 2.5257
# Epoch   0 Batch   60/538 - Train Accuracy: 0.4006, Validation Accuracy: 0.4672, Loss: 2.5113
# Epoch   0 Batch   80/538 - Train Accuracy: 0.4186, Validation Accuracy: 0.4934, Loss: 2.3421
# Epoch   0 Batch  100/538 - Train Accuracy: 0.4627, Validation Accuracy: 0.5123, Loss: 2.1523
# Epoch   0 Batch  120/538 - Train Accuracy: 0.4600, Validation Accuracy: 0.5064, Loss: 2.0509
# Epoch   0 Batch  140/538 - Train Accuracy: 0.4545, Validation Accuracy: 0.5005, Loss: 2.0342
# Epoch   0 Batch  160/538 - Train Accuracy: 0.4637, Validation Accuracy: 0.5050, Loss: 1.7925
# Epoch   0 Batch  180/538 - Train Accuracy: 0.4972, Validation Accuracy: 0.5117, Loss: 1.7403
# Epoch   0 Batch  200/538 - Train Accuracy: 0.4520, Validation Accuracy: 0.5131, Loss: 1.7215
# Epoch   0 Batch  220/538 - Train Accuracy: 0.4838, Validation Accuracy: 0.5117, Loss: 1.4983
# Epoch   0 Batch  240/538 - Train Accuracy: 0.4789, Validation Accuracy: 0.5222, Loss: 1.4580
# Epoch   0 Batch  260/538 - Train Accuracy: 0.4950, Validation Accuracy: 0.5268, Loss: 1.3637
# Epoch   0 Batch  280/538 - Train Accuracy: 0.5019, Validation Accuracy: 0.5128, Loss: 1.2490
# Epoch   0 Batch  300/538 - Train Accuracy: 0.5279, Validation Accuracy: 0.5359, Loss: 1.2161
# Epoch   0 Batch  320/538 - Train Accuracy: 0.5225, Validation Accuracy: 0.5440, Loss: 1.1761
# Epoch   0 Batch  340/538 - Train Accuracy: 0.4760, Validation Accuracy: 0.5366, Loss: 1.1785
# Epoch   0 Batch  360/538 - Train Accuracy: 0.4777, Validation Accuracy: 0.5293, Loss: 1.1686
# Epoch   0 Batch  380/538 - Train Accuracy: 0.5215, Validation Accuracy: 0.5550, Loss: 1.0928
# Epoch   0 Batch  400/538 - Train Accuracy: 0.5141, Validation Accuracy: 0.5371, Loss: 1.0432
# Epoch   0 Batch  420/538 - Train Accuracy: 0.5053, Validation Accuracy: 0.5311, Loss: 1.0217
# Epoch   0 Batch  440/538 - Train Accuracy: 0.4975, Validation Accuracy: 0.5614, Loss: 1.0243
# Epoch   0 Batch  460/538 - Train Accuracy: 0.5285, Validation Accuracy: 0.5591, Loss: 0.9472
# Epoch   0 Batch  480/538 - Train Accuracy: 0.5688, Validation Accuracy: 0.5650, Loss: 0.9057
# Epoch   0 Batch  500/538 - Train Accuracy: 0.5659, Validation Accuracy: 0.5526, Loss: 0.8320
# Epoch   0 Batch  520/538 - Train Accuracy: 0.5559, Validation Accuracy: 0.5803, Loss: 0.9068
# Epoch   1 Batch   20/538 - Train Accuracy: 0.5618, Validation Accuracy: 0.5888, Loss: 0.8282
# Epoch   1 Batch   40/538 - Train Accuracy: 0.6259, Validation Accuracy: 0.5904, Loss: 0.7254
# Epoch   1 Batch   60/538 - Train Accuracy: 0.5838, Validation Accuracy: 0.6012, Loss: 0.7803
# Epoch   1 Batch   80/538 - Train Accuracy: 0.5793, Validation Accuracy: 0.6072, Loss: 0.8017
# Epoch   1 Batch  100/538 - Train Accuracy: 0.5793, Validation Accuracy: 0.5982, Loss: 0.7366
# Epoch   1 Batch  120/538 - Train Accuracy: 0.5895, Validation Accuracy: 0.5991, Loss: 0.7220
# Epoch   1 Batch  140/538 - Train Accuracy: 0.5568, Validation Accuracy: 0.6053, Loss: 0.7798
# Epoch   1 Batch  160/538 - Train Accuracy: 0.5984, Validation Accuracy: 0.6081, Loss: 0.6763
# Epoch   1 Batch  180/538 - Train Accuracy: 0.6248, Validation Accuracy: 0.6003, Loss: 0.6830
# Epoch   1 Batch  200/538 - Train Accuracy: 0.6178, Validation Accuracy: 0.6158, Loss: 0.6760
# Epoch   1 Batch  220/538 - Train Accuracy: 0.5779, Validation Accuracy: 0.6159, Loss: 0.6534
# Epoch   1 Batch  240/538 - Train Accuracy: 0.6004, Validation Accuracy: 0.6154, Loss: 0.6841
# Epoch   1 Batch  260/538 - Train Accuracy: 0.6109, Validation Accuracy: 0.6234, Loss: 0.6505
# Epoch   1 Batch  280/538 - Train Accuracy: 0.6527, Validation Accuracy: 0.6170, Loss: 0.6177
# Epoch   1 Batch  300/538 - Train Accuracy: 0.6287, Validation Accuracy: 0.6168, Loss: 0.6154
# Epoch   1 Batch  320/538 - Train Accuracy: 0.6341, Validation Accuracy: 0.6291, Loss: 0.6152
# Epoch   1 Batch  340/538 - Train Accuracy: 0.6068, Validation Accuracy: 0.6351, Loss: 0.6334
# Epoch   1 Batch  360/538 - Train Accuracy: 0.6309, Validation Accuracy: 0.6317, Loss: 0.6140
# Epoch   1 Batch  380/538 - Train Accuracy: 0.6008, Validation Accuracy: 0.6261, Loss: 0.5885
# Epoch   1 Batch  400/538 - Train Accuracy: 0.6231, Validation Accuracy: 0.6259, Loss: 0.5828
# Epoch   1 Batch  420/538 - Train Accuracy: 0.6363, Validation Accuracy: 0.6344, Loss: 0.5598
# Epoch   1 Batch  440/538 - Train Accuracy: 0.6279, Validation Accuracy: 0.6460, Loss: 0.5989
# Epoch   1 Batch  460/538 - Train Accuracy: 0.6202, Validation Accuracy: 0.6484, Loss: 0.5439
# Epoch   1 Batch  480/538 - Train Accuracy: 0.6520, Validation Accuracy: 0.6470, Loss: 0.5372
# Epoch   1 Batch  500/538 - Train Accuracy: 0.6628, Validation Accuracy: 0.6463, Loss: 0.4973
# Epoch   1 Batch  520/538 - Train Accuracy: 0.6406, Validation Accuracy: 0.6539, Loss: 0.5615
# Epoch   2 Batch   20/538 - Train Accuracy: 0.6484, Validation Accuracy: 0.6653, Loss: 0.5236
# Epoch   2 Batch   40/538 - Train Accuracy: 0.6886, Validation Accuracy: 0.6525, Loss: 0.4570
# Epoch   2 Batch   60/538 - Train Accuracy: 0.6627, Validation Accuracy: 0.6648, Loss: 0.4982
# Epoch   2 Batch   80/538 - Train Accuracy: 0.6588, Validation Accuracy: 0.6719, Loss: 0.5173
# Epoch   2 Batch  100/538 - Train Accuracy: 0.6740, Validation Accuracy: 0.6744, Loss: 0.4697
# Epoch   2 Batch  120/538 - Train Accuracy: 0.6816, Validation Accuracy: 0.6799, Loss: 0.4567
# Epoch   2 Batch  140/538 - Train Accuracy: 0.6275, Validation Accuracy: 0.6804, Loss: 0.4961
# Epoch   2 Batch  160/538 - Train Accuracy: 0.6717, Validation Accuracy: 0.6946, Loss: 0.4428
# Epoch   2 Batch  180/538 - Train Accuracy: 0.7059, Validation Accuracy: 0.6834, Loss: 0.4445
# Epoch   2 Batch  200/538 - Train Accuracy: 0.6973, Validation Accuracy: 0.6740, Loss: 0.4378
# Epoch   2 Batch  220/538 - Train Accuracy: 0.6817, Validation Accuracy: 0.6614, Loss: 0.4240
# Epoch   2 Batch  240/538 - Train Accuracy: 0.6834, Validation Accuracy: 0.6772, Loss: 0.4332
# Epoch   2 Batch  260/538 - Train Accuracy: 0.6762, Validation Accuracy: 0.6866, Loss: 0.4203
# Epoch   2 Batch  280/538 - Train Accuracy: 0.7096, Validation Accuracy: 0.6786, Loss: 0.4010
# Epoch   2 Batch  300/538 - Train Accuracy: 0.7230, Validation Accuracy: 0.6928, Loss: 0.3926
# Epoch   2 Batch  320/538 - Train Accuracy: 0.6951, Validation Accuracy: 0.6873, Loss: 0.3928
# Epoch   2 Batch  340/538 - Train Accuracy: 0.7121, Validation Accuracy: 0.7077, Loss: 0.4015
# Epoch   2 Batch  360/538 - Train Accuracy: 0.6939, Validation Accuracy: 0.7168, Loss: 0.3871
# Epoch   2 Batch  380/538 - Train Accuracy: 0.7219, Validation Accuracy: 0.7097, Loss: 0.3597
# Epoch   2 Batch  400/538 - Train Accuracy: 0.7052, Validation Accuracy: 0.7001, Loss: 0.3759
# Epoch   2 Batch  420/538 - Train Accuracy: 0.7434, Validation Accuracy: 0.6978, Loss: 0.3551
# Epoch   2 Batch  440/538 - Train Accuracy: 0.7143, Validation Accuracy: 0.7012, Loss: 0.3754
# Epoch   2 Batch  460/538 - Train Accuracy: 0.7253, Validation Accuracy: 0.7156, Loss: 0.3370
# Epoch   2 Batch  480/538 - Train Accuracy: 0.7725, Validation Accuracy: 0.7312, Loss: 0.3272
# Epoch   2 Batch  500/538 - Train Accuracy: 0.7772, Validation Accuracy: 0.7301, Loss: 0.2982
# Epoch   2 Batch  520/538 - Train Accuracy: 0.7527, Validation Accuracy: 0.7409, Loss: 0.3197
# Epoch   3 Batch   20/538 - Train Accuracy: 0.7677, Validation Accuracy: 0.7598, Loss: 0.3060
# Epoch   3 Batch   40/538 - Train Accuracy: 0.7793, Validation Accuracy: 0.7566, Loss: 0.2625
# Epoch   3 Batch   60/538 - Train Accuracy: 0.7740, Validation Accuracy: 0.7532, Loss: 0.2824
# Epoch   3 Batch   80/538 - Train Accuracy: 0.7717, Validation Accuracy: 0.7500, Loss: 0.3093
# Epoch   3 Batch  100/538 - Train Accuracy: 0.8105, Validation Accuracy: 0.7740, Loss: 0.2630
# Epoch   3 Batch  120/538 - Train Accuracy: 0.7881, Validation Accuracy: 0.7642, Loss: 0.2497
# Epoch   3 Batch  140/538 - Train Accuracy: 0.7477, Validation Accuracy: 0.7532, Loss: 0.2938
# Epoch   3 Batch  160/538 - Train Accuracy: 0.7805, Validation Accuracy: 0.7773, Loss: 0.2504
# Epoch   3 Batch  180/538 - Train Accuracy: 0.8108, Validation Accuracy: 0.7694, Loss: 0.2448
# Epoch   3 Batch  200/538 - Train Accuracy: 0.8098, Validation Accuracy: 0.7795, Loss: 0.2577
# Epoch   3 Batch  220/538 - Train Accuracy: 0.7842, Validation Accuracy: 0.7733, Loss: 0.2400
# Epoch   3 Batch  240/538 - Train Accuracy: 0.8139, Validation Accuracy: 0.7741, Loss: 0.2462
# Epoch   3 Batch  260/538 - Train Accuracy: 0.7818, Validation Accuracy: 0.7752, Loss: 0.2279
# Epoch   3 Batch  280/538 - Train Accuracy: 0.8348, Validation Accuracy: 0.7795, Loss: 0.2151
# Epoch   3 Batch  300/538 - Train Accuracy: 0.8212, Validation Accuracy: 0.7786, Loss: 0.2245
# Epoch   3 Batch  320/538 - Train Accuracy: 0.8065, Validation Accuracy: 0.7846, Loss: 0.2113
# Epoch   3 Batch  340/538 - Train Accuracy: 0.8064, Validation Accuracy: 0.7885, Loss: 0.2164
# Epoch   3 Batch  360/538 - Train Accuracy: 0.8068, Validation Accuracy: 0.7994, Loss: 0.2066
# Epoch   3 Batch  380/538 - Train Accuracy: 0.8162, Validation Accuracy: 0.8125, Loss: 0.1896
# Epoch   3 Batch  400/538 - Train Accuracy: 0.8415, Validation Accuracy: 0.8148, Loss: 0.2007
# Epoch   3 Batch  420/538 - Train Accuracy: 0.8393, Validation Accuracy: 0.8084, Loss: 0.1882
# Epoch   3 Batch  440/538 - Train Accuracy: 0.8332, Validation Accuracy: 0.8335, Loss: 0.2106
# Epoch   3 Batch  460/538 - Train Accuracy: 0.8493, Validation Accuracy: 0.8272, Loss: 0.1922
# Epoch   3 Batch  480/538 - Train Accuracy: 0.8532, Validation Accuracy: 0.8129, Loss: 0.1774
# Epoch   3 Batch  500/538 - Train Accuracy: 0.8936, Validation Accuracy: 0.8551, Loss: 0.1532
# Epoch   3 Batch  520/538 - Train Accuracy: 0.8693, Validation Accuracy: 0.8544, Loss: 0.1817
# Epoch   4 Batch   20/538 - Train Accuracy: 0.8906, Validation Accuracy: 0.8667, Loss: 0.1793
# Epoch   4 Batch   40/538 - Train Accuracy: 0.9018, Validation Accuracy: 0.8564, Loss: 0.1351
# Epoch   4 Batch   60/538 - Train Accuracy: 0.8766, Validation Accuracy: 0.8567, Loss: 0.1587
# Epoch   4 Batch   80/538 - Train Accuracy: 0.8992, Validation Accuracy: 0.8743, Loss: 0.1693
# Epoch   4 Batch  100/538 - Train Accuracy: 0.9133, Validation Accuracy: 0.8757, Loss: 0.1347
# Epoch   4 Batch  120/538 - Train Accuracy: 0.9023, Validation Accuracy: 0.8780, Loss: 0.1346
# Epoch   4 Batch  140/538 - Train Accuracy: 0.8854, Validation Accuracy: 0.8683, Loss: 0.1664
# Epoch   4 Batch  160/538 - Train Accuracy: 0.8817, Validation Accuracy: 0.8755, Loss: 0.1312
# Epoch   4 Batch  180/538 - Train Accuracy: 0.9035, Validation Accuracy: 0.8672, Loss: 0.1363
# Epoch   4 Batch  200/538 - Train Accuracy: 0.8943, Validation Accuracy: 0.8565, Loss: 0.1371
# Epoch   4 Batch  220/538 - Train Accuracy: 0.8867, Validation Accuracy: 0.8741, Loss: 0.1316
# Epoch   4 Batch  240/538 - Train Accuracy: 0.8943, Validation Accuracy: 0.8691, Loss: 0.1356
# Epoch   4 Batch  260/538 - Train Accuracy: 0.8903, Validation Accuracy: 0.8642, Loss: 0.1317
# Epoch   4 Batch  280/538 - Train Accuracy: 0.9124, Validation Accuracy: 0.8780, Loss: 0.1309
# Epoch   4 Batch  300/538 - Train Accuracy: 0.9001, Validation Accuracy: 0.8812, Loss: 0.1277
# Epoch   4 Batch  320/538 - Train Accuracy: 0.8925, Validation Accuracy: 0.8844, Loss: 0.1246
# Epoch   4 Batch  340/538 - Train Accuracy: 0.8803, Validation Accuracy: 0.8837, Loss: 0.1312
# Epoch   4 Batch  360/538 - Train Accuracy: 0.8887, Validation Accuracy: 0.8732, Loss: 0.1238
# Epoch   4 Batch  380/538 - Train Accuracy: 0.8988, Validation Accuracy: 0.8940, Loss: 0.1114
# Epoch   4 Batch  400/538 - Train Accuracy: 0.9180, Validation Accuracy: 0.9029, Loss: 0.1158
# Epoch   4 Batch  420/538 - Train Accuracy: 0.9168, Validation Accuracy: 0.8952, Loss: 0.1115
# Epoch   4 Batch  440/538 - Train Accuracy: 0.8938, Validation Accuracy: 0.8993, Loss: 0.1218
# Epoch   4 Batch  460/538 - Train Accuracy: 0.8984, Validation Accuracy: 0.8867, Loss: 0.1236
# Epoch   4 Batch  480/538 - Train Accuracy: 0.9258, Validation Accuracy: 0.9034, Loss: 0.1110
# Epoch   4 Batch  500/538 - Train Accuracy: 0.9352, Validation Accuracy: 0.9107, Loss: 0.0940
# Epoch   4 Batch  520/538 - Train Accuracy: 0.9180, Validation Accuracy: 0.8832, Loss: 0.1038
# Epoch   5 Batch   20/538 - Train Accuracy: 0.9068, Validation Accuracy: 0.8979, Loss: 0.1015
# Epoch   5 Batch   40/538 - Train Accuracy: 0.9256, Validation Accuracy: 0.9121, Loss: 0.0870
# Epoch   5 Batch   60/538 - Train Accuracy: 0.9275, Validation Accuracy: 0.9116, Loss: 0.0953
# Epoch   5 Batch   80/538 - Train Accuracy: 0.9205, Validation Accuracy: 0.8986, Loss: 0.1021
# Epoch   5 Batch  100/538 - Train Accuracy: 0.9133, Validation Accuracy: 0.9119, Loss: 0.0829
# Epoch   5 Batch  120/538 - Train Accuracy: 0.9154, Validation Accuracy: 0.8931, Loss: 0.0763
# Epoch   5 Batch  140/538 - Train Accuracy: 0.8996, Validation Accuracy: 0.9251, Loss: 0.1069
# Epoch   5 Batch  160/538 - Train Accuracy: 0.9157, Validation Accuracy: 0.9128, Loss: 0.0828
# Epoch   5 Batch  180/538 - Train Accuracy: 0.9263, Validation Accuracy: 0.8991, Loss: 0.0833
# Epoch   5 Batch  200/538 - Train Accuracy: 0.9252, Validation Accuracy: 0.9094, Loss: 0.0827
# Epoch   5 Batch  220/538 - Train Accuracy: 0.9025, Validation Accuracy: 0.9199, Loss: 0.0838
# Epoch   5 Batch  240/538 - Train Accuracy: 0.9187, Validation Accuracy: 0.9256, Loss: 0.0880
# Epoch   5 Batch  260/538 - Train Accuracy: 0.8943, Validation Accuracy: 0.8999, Loss: 0.0824
# Epoch   5 Batch  280/538 - Train Accuracy: 0.9295, Validation Accuracy: 0.9102, Loss: 0.0712
# Epoch   5 Batch  300/538 - Train Accuracy: 0.9174, Validation Accuracy: 0.9103, Loss: 0.0820
# Epoch   5 Batch  320/538 - Train Accuracy: 0.9141, Validation Accuracy: 0.9171, Loss: 0.0757
# Epoch   5 Batch  340/538 - Train Accuracy: 0.9205, Validation Accuracy: 0.9324, Loss: 0.0853
# Epoch   5 Batch  360/538 - Train Accuracy: 0.9359, Validation Accuracy: 0.9254, Loss: 0.0774
# Epoch   5 Batch  380/538 - Train Accuracy: 0.9168, Validation Accuracy: 0.9110, Loss: 0.0691
# Epoch   5 Batch  400/538 - Train Accuracy: 0.9377, Validation Accuracy: 0.9194, Loss: 0.0759
# Epoch   5 Batch  420/538 - Train Accuracy: 0.9469, Validation Accuracy: 0.9324, Loss: 0.0662
# Epoch   5 Batch  440/538 - Train Accuracy: 0.9086, Validation Accuracy: 0.9306, Loss: 0.0764
# Epoch   5 Batch  460/538 - Train Accuracy: 0.9209, Validation Accuracy: 0.9300, Loss: 0.0748
# Epoch   5 Batch  480/538 - Train Accuracy: 0.9487, Validation Accuracy: 0.9228, Loss: 0.0595
# Epoch   5 Batch  500/538 - Train Accuracy: 0.9402, Validation Accuracy: 0.9251, Loss: 0.0547
# Epoch   5 Batch  520/538 - Train Accuracy: 0.9381, Validation Accuracy: 0.9299, Loss: 0.0632
# Epoch   6 Batch   20/538 - Train Accuracy: 0.9267, Validation Accuracy: 0.9343, Loss: 0.0672
# Epoch   6 Batch   40/538 - Train Accuracy: 0.9322, Validation Accuracy: 0.9256, Loss: 0.0579
# Epoch   6 Batch   60/538 - Train Accuracy: 0.9285, Validation Accuracy: 0.9318, Loss: 0.0649
# Epoch   6 Batch   80/538 - Train Accuracy: 0.9348, Validation Accuracy: 0.9288, Loss: 0.0666
# Epoch   6 Batch  100/538 - Train Accuracy: 0.9453, Validation Accuracy: 0.9368, Loss: 0.0521
# Epoch   6 Batch  120/538 - Train Accuracy: 0.9445, Validation Accuracy: 0.9350, Loss: 0.0497
# Epoch   6 Batch  140/538 - Train Accuracy: 0.9213, Validation Accuracy: 0.9329, Loss: 0.0792
# Epoch   6 Batch  160/538 - Train Accuracy: 0.9275, Validation Accuracy: 0.9290, Loss: 0.0519
# Epoch   6 Batch  180/538 - Train Accuracy: 0.9435, Validation Accuracy: 0.9286, Loss: 0.0640
# Epoch   6 Batch  200/538 - Train Accuracy: 0.9430, Validation Accuracy: 0.9247, Loss: 0.0547
# Epoch   6 Batch  220/538 - Train Accuracy: 0.9131, Validation Accuracy: 0.9288, Loss: 0.0617
# Epoch   6 Batch  240/538 - Train Accuracy: 0.9439, Validation Accuracy: 0.9309, Loss: 0.0616
# Epoch   6 Batch  260/538 - Train Accuracy: 0.9146, Validation Accuracy: 0.9284, Loss: 0.0604
# Epoch   6 Batch  280/538 - Train Accuracy: 0.9408, Validation Accuracy: 0.9249, Loss: 0.0540
# Epoch   6 Batch  300/538 - Train Accuracy: 0.9347, Validation Accuracy: 0.9217, Loss: 0.0575
# Epoch   6 Batch  320/538 - Train Accuracy: 0.9377, Validation Accuracy: 0.9263, Loss: 0.0513
# Epoch   6 Batch  340/538 - Train Accuracy: 0.9330, Validation Accuracy: 0.9389, Loss: 0.0563
# Epoch   6 Batch  360/538 - Train Accuracy: 0.9385, Validation Accuracy: 0.9393, Loss: 0.0544
# Epoch   6 Batch  380/538 - Train Accuracy: 0.9344, Validation Accuracy: 0.9434, Loss: 0.0539
# Epoch   6 Batch  400/538 - Train Accuracy: 0.9466, Validation Accuracy: 0.9379, Loss: 0.0552
# Epoch   6 Batch  420/538 - Train Accuracy: 0.9504, Validation Accuracy: 0.9260, Loss: 0.0558
# Epoch   6 Batch  440/538 - Train Accuracy: 0.9160, Validation Accuracy: 0.9387, Loss: 0.0589
# Epoch   6 Batch  460/538 - Train Accuracy: 0.9141, Validation Accuracy: 0.9483, Loss: 0.0544
# Epoch   6 Batch  480/538 - Train Accuracy: 0.9518, Validation Accuracy: 0.9407, Loss: 0.0505
# Epoch   6 Batch  500/538 - Train Accuracy: 0.9615, Validation Accuracy: 0.9393, Loss: 0.0381
# Epoch   6 Batch  520/538 - Train Accuracy: 0.9555, Validation Accuracy: 0.9311, Loss: 0.0554
# Epoch   7 Batch   20/538 - Train Accuracy: 0.9330, Validation Accuracy: 0.9395, Loss: 0.0486
# Epoch   7 Batch   40/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9426, Loss: 0.0487
# Epoch   7 Batch   60/538 - Train Accuracy: 0.9486, Validation Accuracy: 0.9471, Loss: 0.0518
# Epoch   7 Batch   80/538 - Train Accuracy: 0.9430, Validation Accuracy: 0.9448, Loss: 0.0557
# Epoch   7 Batch  100/538 - Train Accuracy: 0.9486, Validation Accuracy: 0.9437, Loss: 0.0455
# Epoch   7 Batch  120/538 - Train Accuracy: 0.9461, Validation Accuracy: 0.9496, Loss: 0.0412
# Epoch   7 Batch  140/538 - Train Accuracy: 0.9174, Validation Accuracy: 0.9384, Loss: 0.0590
# Epoch   7 Batch  160/538 - Train Accuracy: 0.9381, Validation Accuracy: 0.9396, Loss: 0.0423
# Epoch   7 Batch  180/538 - Train Accuracy: 0.9474, Validation Accuracy: 0.9355, Loss: 0.0508
# Epoch   7 Batch  200/538 - Train Accuracy: 0.9561, Validation Accuracy: 0.9428, Loss: 0.0413
# Epoch   7 Batch  220/538 - Train Accuracy: 0.9366, Validation Accuracy: 0.9451, Loss: 0.0509
# Epoch   7 Batch  240/538 - Train Accuracy: 0.9416, Validation Accuracy: 0.9359, Loss: 0.0539
# Epoch   7 Batch  260/538 - Train Accuracy: 0.9258, Validation Accuracy: 0.9297, Loss: 0.0516
# Epoch   7 Batch  280/538 - Train Accuracy: 0.9442, Validation Accuracy: 0.9416, Loss: 0.0395
# Epoch   7 Batch  300/538 - Train Accuracy: 0.9375, Validation Accuracy: 0.9405, Loss: 0.0525
# Epoch   7 Batch  320/538 - Train Accuracy: 0.9505, Validation Accuracy: 0.9418, Loss: 0.0469
# Epoch   7 Batch  340/538 - Train Accuracy: 0.9354, Validation Accuracy: 0.9432, Loss: 0.0505
# Epoch   7 Batch  360/538 - Train Accuracy: 0.9436, Validation Accuracy: 0.9537, Loss: 0.0438
# Epoch   7 Batch  380/538 - Train Accuracy: 0.9375, Validation Accuracy: 0.9533, Loss: 0.0388
# Epoch   7 Batch  400/538 - Train Accuracy: 0.9606, Validation Accuracy: 0.9450, Loss: 0.0418
# Epoch   7 Batch  420/538 - Train Accuracy: 0.9502, Validation Accuracy: 0.9412, Loss: 0.0470
# Epoch   7 Batch  440/538 - Train Accuracy: 0.9498, Validation Accuracy: 0.9471, Loss: 0.0483
# Epoch   7 Batch  460/538 - Train Accuracy: 0.9422, Validation Accuracy: 0.9471, Loss: 0.0476
# Epoch   7 Batch  480/538 - Train Accuracy: 0.9567, Validation Accuracy: 0.9471, Loss: 0.0476
# Epoch   7 Batch  500/538 - Train Accuracy: 0.9586, Validation Accuracy: 0.9485, Loss: 0.0443
# Epoch   7 Batch  520/538 - Train Accuracy: 0.9518, Validation Accuracy: 0.9503, Loss: 0.0475
# Epoch   8 Batch   20/538 - Train Accuracy: 0.9435, Validation Accuracy: 0.9501, Loss: 0.0423
# Epoch   8 Batch   40/538 - Train Accuracy: 0.9396, Validation Accuracy: 0.9387, Loss: 0.0389
# Epoch   8 Batch   60/538 - Train Accuracy: 0.9426, Validation Accuracy: 0.9416, Loss: 0.0439
# Epoch   8 Batch   80/538 - Train Accuracy: 0.9520, Validation Accuracy: 0.9492, Loss: 0.0426
# Epoch   8 Batch  100/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9473, Loss: 0.0342
# Epoch   8 Batch  120/538 - Train Accuracy: 0.9602, Validation Accuracy: 0.9567, Loss: 0.0300
# Epoch   8 Batch  140/538 - Train Accuracy: 0.9361, Validation Accuracy: 0.9542, Loss: 0.0501
# Epoch   8 Batch  160/538 - Train Accuracy: 0.9390, Validation Accuracy: 0.9430, Loss: 0.0403
# Epoch   8 Batch  180/538 - Train Accuracy: 0.9602, Validation Accuracy: 0.9418, Loss: 0.0402
# Epoch   8 Batch  200/538 - Train Accuracy: 0.9727, Validation Accuracy: 0.9474, Loss: 0.0337
# Epoch   8 Batch  220/538 - Train Accuracy: 0.9349, Validation Accuracy: 0.9528, Loss: 0.0462
# Epoch   8 Batch  240/538 - Train Accuracy: 0.9451, Validation Accuracy: 0.9473, Loss: 0.0446
# Epoch   8 Batch  260/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9585, Loss: 0.0447
# Epoch   8 Batch  280/538 - Train Accuracy: 0.9485, Validation Accuracy: 0.9638, Loss: 0.0397
# Epoch   8 Batch  300/538 - Train Accuracy: 0.9492, Validation Accuracy: 0.9505, Loss: 0.0398
# Epoch   8 Batch  320/538 - Train Accuracy: 0.9650, Validation Accuracy: 0.9542, Loss: 0.0364
# Epoch   8 Batch  340/538 - Train Accuracy: 0.9467, Validation Accuracy: 0.9599, Loss: 0.0422
# Epoch   8 Batch  360/538 - Train Accuracy: 0.9568, Validation Accuracy: 0.9632, Loss: 0.0393
# Epoch   8 Batch  380/538 - Train Accuracy: 0.9490, Validation Accuracy: 0.9570, Loss: 0.0376
# Epoch   8 Batch  400/538 - Train Accuracy: 0.9572, Validation Accuracy: 0.9576, Loss: 0.0441
# Epoch   8 Batch  420/538 - Train Accuracy: 0.9578, Validation Accuracy: 0.9483, Loss: 0.0381
# Epoch   8 Batch  440/538 - Train Accuracy: 0.9533, Validation Accuracy: 0.9538, Loss: 0.0440
# Epoch   8 Batch  460/538 - Train Accuracy: 0.9455, Validation Accuracy: 0.9544, Loss: 0.0376
# Epoch   8 Batch  480/538 - Train Accuracy: 0.9743, Validation Accuracy: 0.9480, Loss: 0.0336
# Epoch   8 Batch  500/538 - Train Accuracy: 0.9751, Validation Accuracy: 0.9494, Loss: 0.0262
# Epoch   8 Batch  520/538 - Train Accuracy: 0.9623, Validation Accuracy: 0.9485, Loss: 0.0352
# Epoch   9 Batch   20/538 - Train Accuracy: 0.9518, Validation Accuracy: 0.9622, Loss: 0.0377
# Epoch   9 Batch   40/538 - Train Accuracy: 0.9659, Validation Accuracy: 0.9510, Loss: 0.0333
# Epoch   9 Batch   60/538 - Train Accuracy: 0.9484, Validation Accuracy: 0.9528, Loss: 0.0369
# Epoch   9 Batch   80/538 - Train Accuracy: 0.9654, Validation Accuracy: 0.9492, Loss: 0.0376
# Epoch   9 Batch  100/538 - Train Accuracy: 0.9619, Validation Accuracy: 0.9494, Loss: 0.0346
# Epoch   9 Batch  120/538 - Train Accuracy: 0.9662, Validation Accuracy: 0.9524, Loss: 0.0272
# Epoch   9 Batch  140/538 - Train Accuracy: 0.9344, Validation Accuracy: 0.9538, Loss: 0.0474
# Epoch   9 Batch  160/538 - Train Accuracy: 0.9444, Validation Accuracy: 0.9608, Loss: 0.0323
# Epoch   9 Batch  180/538 - Train Accuracy: 0.9568, Validation Accuracy: 0.9640, Loss: 0.0373
# Epoch   9 Batch  200/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9545, Loss: 0.0433
# Epoch   9 Batch  220/538 - Train Accuracy: 0.9336, Validation Accuracy: 0.9467, Loss: 0.0572
# Epoch   9 Batch  240/538 - Train Accuracy: 0.9559, Validation Accuracy: 0.9585, Loss: 0.0437
# Epoch   9 Batch  260/538 - Train Accuracy: 0.9334, Validation Accuracy: 0.9535, Loss: 0.0361
# Epoch   9 Batch  280/538 - Train Accuracy: 0.9596, Validation Accuracy: 0.9604, Loss: 0.0305
# Epoch   9 Batch  300/538 - Train Accuracy: 0.9468, Validation Accuracy: 0.9553, Loss: 0.0349
# Epoch   9 Batch  320/538 - Train Accuracy: 0.9624, Validation Accuracy: 0.9675, Loss: 0.0327
# Epoch   9 Batch  340/538 - Train Accuracy: 0.9531, Validation Accuracy: 0.9537, Loss: 0.0349
# Epoch   9 Batch  360/538 - Train Accuracy: 0.9662, Validation Accuracy: 0.9656, Loss: 0.0375
# Epoch   9 Batch  380/538 - Train Accuracy: 0.9688, Validation Accuracy: 0.9528, Loss: 0.0288
# Epoch   9 Batch  400/538 - Train Accuracy: 0.9688, Validation Accuracy: 0.9654, Loss: 0.0342
# Epoch   9 Batch  420/538 - Train Accuracy: 0.9574, Validation Accuracy: 0.9714, Loss: 0.0361
# Epoch   9 Batch  440/538 - Train Accuracy: 0.9629, Validation Accuracy: 0.9727, Loss: 0.0351
# Epoch   9 Batch  460/538 - Train Accuracy: 0.9663, Validation Accuracy: 0.9613, Loss: 0.0335
# Epoch   9 Batch  480/538 - Train Accuracy: 0.9710, Validation Accuracy: 0.9521, Loss: 0.0309
# Epoch   9 Batch  500/538 - Train Accuracy: 0.9775, Validation Accuracy: 0.9432, Loss: 0.0228
# Epoch   9 Batch  520/538 - Train Accuracy: 0.9637, Validation Accuracy: 0.9542, Loss: 0.0304
# Epoch  10 Batch   20/538 - Train Accuracy: 0.9622, Validation Accuracy: 0.9560, Loss: 0.0326
# Epoch  10 Batch   40/538 - Train Accuracy: 0.9569, Validation Accuracy: 0.9609, Loss: 0.0280
# Epoch  10 Batch   60/538 - Train Accuracy: 0.9607, Validation Accuracy: 0.9563, Loss: 0.0328
# Epoch  10 Batch   80/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9577, Loss: 0.0356
# Epoch  10 Batch  100/538 - Train Accuracy: 0.9635, Validation Accuracy: 0.9608, Loss: 0.0275
# Epoch  10 Batch  120/538 - Train Accuracy: 0.9721, Validation Accuracy: 0.9641, Loss: 0.0251
# Epoch  10 Batch  140/538 - Train Accuracy: 0.9564, Validation Accuracy: 0.9643, Loss: 0.0384
# Epoch  10 Batch  160/538 - Train Accuracy: 0.9552, Validation Accuracy: 0.9695, Loss: 0.0315
# Epoch  10 Batch  180/538 - Train Accuracy: 0.9568, Validation Accuracy: 0.9684, Loss: 0.0325
# Epoch  10 Batch  200/538 - Train Accuracy: 0.9693, Validation Accuracy: 0.9616, Loss: 0.0261
# Epoch  10 Batch  220/538 - Train Accuracy: 0.9529, Validation Accuracy: 0.9597, Loss: 0.0378
# Epoch  10 Batch  240/538 - Train Accuracy: 0.9529, Validation Accuracy: 0.9585, Loss: 0.0328
# Epoch  10 Batch  260/538 - Train Accuracy: 0.9483, Validation Accuracy: 0.9604, Loss: 0.0327
# Epoch  10 Batch  280/538 - Train Accuracy: 0.9624, Validation Accuracy: 0.9668, Loss: 0.0286
# Epoch  10 Batch  300/538 - Train Accuracy: 0.9626, Validation Accuracy: 0.9666, Loss: 0.0304
# Epoch  10 Batch  320/538 - Train Accuracy: 0.9643, Validation Accuracy: 0.9650, Loss: 0.0298
# Epoch  10 Batch  340/538 - Train Accuracy: 0.9539, Validation Accuracy: 0.9563, Loss: 0.0309
# Epoch  10 Batch  360/538 - Train Accuracy: 0.9648, Validation Accuracy: 0.9680, Loss: 0.0291
# Epoch  10 Batch  380/538 - Train Accuracy: 0.9727, Validation Accuracy: 0.9684, Loss: 0.0286
# Epoch  10 Batch  400/538 - Train Accuracy: 0.9364, Validation Accuracy: 0.9377, Loss: 0.0372
# Epoch  10 Batch  420/538 - Train Accuracy: 0.9529, Validation Accuracy: 0.9629, Loss: 0.0302
# Epoch  10 Batch  440/538 - Train Accuracy: 0.9746, Validation Accuracy: 0.9588, Loss: 0.0328
# Epoch  10 Batch  460/538 - Train Accuracy: 0.9643, Validation Accuracy: 0.9611, Loss: 0.0315
# Epoch  10 Batch  480/538 - Train Accuracy: 0.9808, Validation Accuracy: 0.9652, Loss: 0.0253
# Epoch  10 Batch  500/538 - Train Accuracy: 0.9819, Validation Accuracy: 0.9529, Loss: 0.0224
# Epoch  10 Batch  520/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9613, Loss: 0.0308
# Epoch  11 Batch   20/538 - Train Accuracy: 0.9585, Validation Accuracy: 0.9590, Loss: 0.0331
# Epoch  11 Batch   40/538 - Train Accuracy: 0.9693, Validation Accuracy: 0.9636, Loss: 0.0249
# Epoch  11 Batch   60/538 - Train Accuracy: 0.9789, Validation Accuracy: 0.9695, Loss: 0.0282
# Epoch  11 Batch   80/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9677, Loss: 0.0286
# Epoch  11 Batch  100/538 - Train Accuracy: 0.9568, Validation Accuracy: 0.9613, Loss: 0.0280
# Epoch  11 Batch  120/538 - Train Accuracy: 0.9805, Validation Accuracy: 0.9590, Loss: 0.0194
# Epoch  11 Batch  140/538 - Train Accuracy: 0.9557, Validation Accuracy: 0.9629, Loss: 0.0334
# Epoch  11 Batch  160/538 - Train Accuracy: 0.9585, Validation Accuracy: 0.9650, Loss: 0.0260
# Epoch  11 Batch  180/538 - Train Accuracy: 0.9678, Validation Accuracy: 0.9679, Loss: 0.0268
# Epoch  11 Batch  200/538 - Train Accuracy: 0.9721, Validation Accuracy: 0.9632, Loss: 0.0193
# Epoch  11 Batch  220/538 - Train Accuracy: 0.9567, Validation Accuracy: 0.9684, Loss: 0.0286
# Epoch  11 Batch  240/538 - Train Accuracy: 0.9602, Validation Accuracy: 0.9585, Loss: 0.0283
# Epoch  11 Batch  260/538 - Train Accuracy: 0.9580, Validation Accuracy: 0.9545, Loss: 0.0269
# Epoch  11 Batch  280/538 - Train Accuracy: 0.9734, Validation Accuracy: 0.9691, Loss: 0.0249
# Epoch  11 Batch  300/538 - Train Accuracy: 0.9554, Validation Accuracy: 0.9650, Loss: 0.0285
# Epoch  11 Batch  320/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9595, Loss: 0.0224
# Epoch  11 Batch  340/538 - Train Accuracy: 0.9646, Validation Accuracy: 0.9661, Loss: 0.0245
# Epoch  11 Batch  360/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9638, Loss: 0.0265
# Epoch  11 Batch  380/538 - Train Accuracy: 0.9791, Validation Accuracy: 0.9750, Loss: 0.0250
# Epoch  11 Batch  400/538 - Train Accuracy: 0.9779, Validation Accuracy: 0.9648, Loss: 0.0250
# Epoch  11 Batch  420/538 - Train Accuracy: 0.9660, Validation Accuracy: 0.9643, Loss: 0.0298
# Epoch  11 Batch  440/538 - Train Accuracy: 0.9715, Validation Accuracy: 0.9647, Loss: 0.0279
# Epoch  11 Batch  460/538 - Train Accuracy: 0.9585, Validation Accuracy: 0.9647, Loss: 0.0264
# Epoch  11 Batch  480/538 - Train Accuracy: 0.9794, Validation Accuracy: 0.9608, Loss: 0.0262
# Epoch  11 Batch  500/538 - Train Accuracy: 0.9869, Validation Accuracy: 0.9631, Loss: 0.0187
# Epoch  11 Batch  520/538 - Train Accuracy: 0.9723, Validation Accuracy: 0.9624, Loss: 0.0272
# Epoch  12 Batch   20/538 - Train Accuracy: 0.9663, Validation Accuracy: 0.9597, Loss: 0.0301
# Epoch  12 Batch   40/538 - Train Accuracy: 0.9631, Validation Accuracy: 0.9560, Loss: 0.0210
# Epoch  12 Batch   60/538 - Train Accuracy: 0.9689, Validation Accuracy: 0.9657, Loss: 0.0268
# Epoch  12 Batch   80/538 - Train Accuracy: 0.9670, Validation Accuracy: 0.9711, Loss: 0.0263
# Epoch  12 Batch  100/538 - Train Accuracy: 0.9758, Validation Accuracy: 0.9725, Loss: 0.0186
# Epoch  12 Batch  120/538 - Train Accuracy: 0.9639, Validation Accuracy: 0.9663, Loss: 0.0200
# Epoch  12 Batch  140/538 - Train Accuracy: 0.9609, Validation Accuracy: 0.9505, Loss: 0.0328
# Epoch  12 Batch  160/538 - Train Accuracy: 0.9554, Validation Accuracy: 0.9723, Loss: 0.0236
# Epoch  12 Batch  180/538 - Train Accuracy: 0.9632, Validation Accuracy: 0.9693, Loss: 0.0272
# Epoch  12 Batch  200/538 - Train Accuracy: 0.9820, Validation Accuracy: 0.9581, Loss: 0.0226
# Epoch  12 Batch  220/538 - Train Accuracy: 0.9615, Validation Accuracy: 0.9659, Loss: 0.0285
# Epoch  12 Batch  240/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9648, Loss: 0.0270
# Epoch  12 Batch  260/538 - Train Accuracy: 0.9576, Validation Accuracy: 0.9469, Loss: 0.0246
# Epoch  12 Batch  280/538 - Train Accuracy: 0.9702, Validation Accuracy: 0.9760, Loss: 0.0210
# Epoch  12 Batch  300/538 - Train Accuracy: 0.9706, Validation Accuracy: 0.9629, Loss: 0.0272
# Epoch  12 Batch  320/538 - Train Accuracy: 0.9706, Validation Accuracy: 0.9725, Loss: 0.0232
# Epoch  12 Batch  340/538 - Train Accuracy: 0.9623, Validation Accuracy: 0.9576, Loss: 0.0260
# Epoch  12 Batch  360/538 - Train Accuracy: 0.9660, Validation Accuracy: 0.9647, Loss: 0.0255
# Epoch  12 Batch  380/538 - Train Accuracy: 0.9807, Validation Accuracy: 0.9650, Loss: 0.0187
# Epoch  12 Batch  400/538 - Train Accuracy: 0.9799, Validation Accuracy: 0.9679, Loss: 0.0237
# Epoch  12 Batch  420/538 - Train Accuracy: 0.9713, Validation Accuracy: 0.9691, Loss: 0.0278
# Epoch  12 Batch  440/538 - Train Accuracy: 0.9795, Validation Accuracy: 0.9712, Loss: 0.0223
# Epoch  12 Batch  460/538 - Train Accuracy: 0.9773, Validation Accuracy: 0.9592, Loss: 0.0241
# Epoch  12 Batch  480/538 - Train Accuracy: 0.9862, Validation Accuracy: 0.9712, Loss: 0.0236
# Epoch  12 Batch  500/538 - Train Accuracy: 0.9885, Validation Accuracy: 0.9709, Loss: 0.0143
# Epoch  12 Batch  520/538 - Train Accuracy: 0.9723, Validation Accuracy: 0.9561, Loss: 0.0284
# Epoch  13 Batch   20/538 - Train Accuracy: 0.9704, Validation Accuracy: 0.9567, Loss: 0.0262
# Epoch  13 Batch   40/538 - Train Accuracy: 0.9815, Validation Accuracy: 0.9631, Loss: 0.0164
# Epoch  13 Batch   60/538 - Train Accuracy: 0.9762, Validation Accuracy: 0.9773, Loss: 0.0253
# Epoch  13 Batch   80/538 - Train Accuracy: 0.9756, Validation Accuracy: 0.9759, Loss: 0.0220
# Epoch  13 Batch  100/538 - Train Accuracy: 0.9742, Validation Accuracy: 0.9698, Loss: 0.0176
# Epoch  13 Batch  120/538 - Train Accuracy: 0.9811, Validation Accuracy: 0.9703, Loss: 0.0195
# Epoch  13 Batch  140/538 - Train Accuracy: 0.9707, Validation Accuracy: 0.9593, Loss: 0.0289
# Epoch  13 Batch  160/538 - Train Accuracy: 0.9719, Validation Accuracy: 0.9767, Loss: 0.0210
# Epoch  13 Batch  180/538 - Train Accuracy: 0.9727, Validation Accuracy: 0.9700, Loss: 0.0242
# Epoch  13 Batch  200/538 - Train Accuracy: 0.9777, Validation Accuracy: 0.9663, Loss: 0.0190
# Epoch  13 Batch  220/538 - Train Accuracy: 0.9572, Validation Accuracy: 0.9680, Loss: 0.0258
# Epoch  13 Batch  240/538 - Train Accuracy: 0.9637, Validation Accuracy: 0.9597, Loss: 0.0304
# Epoch  13 Batch  260/538 - Train Accuracy: 0.9581, Validation Accuracy: 0.9661, Loss: 0.0277
# Epoch  13 Batch  280/538 - Train Accuracy: 0.9801, Validation Accuracy: 0.9712, Loss: 0.0204
# Epoch  13 Batch  300/538 - Train Accuracy: 0.9699, Validation Accuracy: 0.9652, Loss: 0.0224
# Epoch  13 Batch  320/538 - Train Accuracy: 0.9669, Validation Accuracy: 0.9703, Loss: 0.0197
# Epoch  13 Batch  340/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9679, Loss: 0.0223
# Epoch  13 Batch  360/538 - Train Accuracy: 0.9713, Validation Accuracy: 0.9634, Loss: 0.0185
# Epoch  13 Batch  380/538 - Train Accuracy: 0.9852, Validation Accuracy: 0.9609, Loss: 0.0195
# Epoch  13 Batch  400/538 - Train Accuracy: 0.9741, Validation Accuracy: 0.9643, Loss: 0.0244
# Epoch  13 Batch  420/538 - Train Accuracy: 0.9662, Validation Accuracy: 0.9718, Loss: 0.0233
# Epoch  13 Batch  440/538 - Train Accuracy: 0.9848, Validation Accuracy: 0.9741, Loss: 0.0202
# Epoch  13 Batch  460/538 - Train Accuracy: 0.9719, Validation Accuracy: 0.9799, Loss: 0.0224
# Epoch  13 Batch  480/538 - Train Accuracy: 0.9860, Validation Accuracy: 0.9627, Loss: 0.0257
# Epoch  13 Batch  500/538 - Train Accuracy: 0.9934, Validation Accuracy: 0.9654, Loss: 0.0136
# Epoch  13 Batch  520/538 - Train Accuracy: 0.9770, Validation Accuracy: 0.9757, Loss: 0.0228
# Epoch  14 Batch   20/538 - Train Accuracy: 0.9766, Validation Accuracy: 0.9682, Loss: 0.0197
# Epoch  14 Batch   40/538 - Train Accuracy: 0.9712, Validation Accuracy: 0.9673, Loss: 0.0177
# Epoch  14 Batch   60/538 - Train Accuracy: 0.9770, Validation Accuracy: 0.9652, Loss: 0.0240
# Epoch  14 Batch   80/538 - Train Accuracy: 0.9727, Validation Accuracy: 0.9801, Loss: 0.0193
# Epoch  14 Batch  100/538 - Train Accuracy: 0.9863, Validation Accuracy: 0.9698, Loss: 0.0149
# Epoch  14 Batch  120/538 - Train Accuracy: 0.9775, Validation Accuracy: 0.9799, Loss: 0.0142
# Epoch  14 Batch  140/538 - Train Accuracy: 0.9721, Validation Accuracy: 0.9627, Loss: 0.0259
# Epoch  14 Batch  160/538 - Train Accuracy: 0.9714, Validation Accuracy: 0.9611, Loss: 0.0190
# Epoch  14 Batch  180/538 - Train Accuracy: 0.9676, Validation Accuracy: 0.9712, Loss: 0.0234
# Epoch  14 Batch  200/538 - Train Accuracy: 0.9787, Validation Accuracy: 0.9771, Loss: 0.0189
# Epoch  14 Batch  220/538 - Train Accuracy: 0.9663, Validation Accuracy: 0.9746, Loss: 0.0225
# Epoch  14 Batch  240/538 - Train Accuracy: 0.9717, Validation Accuracy: 0.9680, Loss: 0.0223
# Epoch  14 Batch  260/538 - Train Accuracy: 0.9505, Validation Accuracy: 0.9705, Loss: 0.0273
# Epoch  14 Batch  280/538 - Train Accuracy: 0.9827, Validation Accuracy: 0.9764, Loss: 0.0184
# Epoch  14 Batch  300/538 - Train Accuracy: 0.9784, Validation Accuracy: 0.9725, Loss: 0.0193
# Epoch  14 Batch  320/538 - Train Accuracy: 0.9779, Validation Accuracy: 0.9796, Loss: 0.0205
# Epoch  14 Batch  340/538 - Train Accuracy: 0.9615, Validation Accuracy: 0.9709, Loss: 0.0188
# Epoch  14 Batch  360/538 - Train Accuracy: 0.9791, Validation Accuracy: 0.9654, Loss: 0.0171
# Epoch  14 Batch  380/538 - Train Accuracy: 0.9816, Validation Accuracy: 0.9693, Loss: 0.0162
# Epoch  14 Batch  400/538 - Train Accuracy: 0.9836, Validation Accuracy: 0.9767, Loss: 0.0198
# Epoch  14 Batch  420/538 - Train Accuracy: 0.9797, Validation Accuracy: 0.9750, Loss: 0.0214
# Epoch  14 Batch  440/538 - Train Accuracy: 0.9857, Validation Accuracy: 0.9835, Loss: 0.0194
# Epoch  14 Batch  460/538 - Train Accuracy: 0.9788, Validation Accuracy: 0.9734, Loss: 0.0205
# Epoch  14 Batch  480/538 - Train Accuracy: 0.9859, Validation Accuracy: 0.9686, Loss: 0.0166
# Epoch  14 Batch  500/538 - Train Accuracy: 0.9867, Validation Accuracy: 0.9757, Loss: 0.0124
# Epoch  14 Batch  520/538 - Train Accuracy: 0.9707, Validation Accuracy: 0.9716, Loss: 0.0239
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    sentence = sentence.lower()
    output = []
    for word in sentence.split(" "):
        if word in vocab_to_int.keys():
            output.append(vocab_to_int[word])
        else:
            output.append(vocab_to_int["<UNK>"])
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [121, 11, 196, 68, 193, 217, 195]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [356, 163, 299, 144, 169, 124, 252, 1]
#   French Words: il a vu un vieux jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
